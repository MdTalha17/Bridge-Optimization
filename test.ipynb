# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("D:\\Projects\\bridge-optimization\\data\\optimization_dataset.csv")

# %%
df.head()
# Out:
#    span_m  carriageway_width_m include_median  footpath  skew_angle_deg  \
# 0    20.0                 4.25             No       NaN             0.0
# 1    20.0                 4.25             No       NaN             0.0
# 2    20.0                 4.25             No       NaN             0.0
# 3    20.0                 4.25             No       NaN             0.0
# 4    20.0                 4.25             No       NaN             0.0
#
#    index    round  gen  n  spacing_m  ...    D_mm  bf_mm  tf_mm  tw_mm  \
# 0      1  Initial    0  2      2.575  ...  1320.0  295.0   45.0   22.0
# 1      2  Initial    0  2      2.575  ...  1050.0  260.0   56.0   12.0
# 2      3  Initial    0  2      2.575  ...  1220.0  375.0   80.0   36.0
# 3      4  Initial    0  2      2.575  ...  1160.0  385.0   80.0   10.0
# 4      5  Initial    0  2      2.575  ...  1180.0  285.0  100.0   36.0
#
#     dw_mm  steel_kN  deck_kN  total_kN  feasible  status
# ...

# %%
df.tail()
# Out:
#        span_m  carriageway_width_m include_median  footpath  skew_angle_deg  \
# 20195    30.0                 4.25             No       NaN             0.0
# 20196    30.0                 4.25             No       NaN             0.0
# 20197    30.0                 4.25             No       NaN             0.0
# 20198    30.0                 4.25             No       NaN             0.0
# 20199    30.0                 4.25             No       NaN             0.0
#
#        index  round  gen  n  spacing_m  ...    D_mm  bf_mm  tf_mm  tw_mm  \
# 20195    196  Gen 3    3  5      1.030  ...  2000.0  595.0  100.0   40.0
# 20196    197  Gen 3    3  5      1.030  ...  1610.0  370.0   16.0    8.0
# 20197    198  Gen 3    3  4      1.288  ...  1220.0  355.0   28.0   40.0
# 20198    199  Gen 3    3  4      1.288  ...  1860.0  730.0    8.0   36.0
# 20199    200  Gen 3    3  5      1.030  ...  1360.0  425.0   12.0   36.0
#
#         dw_mm  steel_kN  deck_kN  total_kN  feasible  status
# ...

# %%
df.describe()
# Out:
#              span_m  carriageway_width_m  footpath  skew_angle_deg  \
# count  20200.000000             20200.00       0.0         20200.0
# mean      25.000000                 4.25       NaN             0.0
# std        2.915548                 0.00       NaN             0.0
# min       20.000000                 4.25       NaN             0.0
# 25%       22.500000                 4.25       NaN             0.0
# 50%       25.000000                 4.25       NaN             0.0
# 75%       27.500000                 4.25       NaN             0.0
# max       30.000000                 4.25       NaN             0.0
#
#               index           gen             n     spacing_m     t_slab_mm  \
# count  20200.000000  20200.000000  20200.000000  20200.000000  20200.000000
# mean     100.500000      1.500000      3.505545      1.599864    194.092079
# std       57.735734      1.118062      0.952544      0.501238     34.889618
# ...

# %%
df.isnull().sum()
# Out:
# span_m                     0
# carriageway_width_m        0
# include_median             0
# footpath               20200
# skew_angle_deg             0
# index                      0
# round                      0
# gen                        0
# n                          0
# spacing_m                  0
# t_slab_mm                  0
# D_mm                       0
# bf_mm                      0
# tf_mm                      0
# tw_mm                      0
# dw_mm                      0
# steel_kN                   0
# deck_kN                    0
# total_kN                   0
# feasible                   0
# status                     0
# dtype: int64
